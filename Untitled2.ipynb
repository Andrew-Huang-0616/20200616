# %% [markdown]
# <a href="https://colab.research.google.com/github/Andrew-Huang-0616/20200616/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pillow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from PIL import Image

# %%
im = Image.open("tree-736885__480.jpg")

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=771x480 at 0x7FB171E22690>

# %%
im.size
# Out:
# (771, 480)

# %%
im=im.resize((85,53))

# %%
im.format
# Out:
# 'JPEG'

# %%
im.mode
# Out:
# 'RGB'

# %%
im_rgb.save ("tree-736885__480.jpg")

# %%
im_rgb = im.convert("RGB")

# %%
r, g, b, = im_rgb.split()
im_rgb = Image.merge("RGB", (b, g, r))

# %%
im_rgb
# Out:
# <PIL.Image.Image image mode=RGB size=771x480 at 0x7FB17173AA90>

# %%
im_rgb.transpose(Image.FLIP_LEFT_RIGHT)
# Out:
# <PIL.Image.Image image mode=RGB size=771x480 at 0x7FB171721050>

# %%
im_rgb.transpose(Image.ROTATE_90)
# Out:
# <PIL.Image.Image image mode=RGB size=480x771 at 0x7FB17173A350>

# %%
im_rgb.resize((257,160))
# Out:
# <PIL.Image.Image image mode=RGB size=257x160 at 0x7FB17172ED90>

# %%
im_rgb.size
# Out:
# (771, 480)

# %%
im_rgb=im_rgb.resize((im_rgb.size[0]//3,im_rgb.size[1]//3))

# %%
im_rgb=im_rgb.resize((im_rgb.size[0]//3,im_rgb.size[1]//3))

# %%
im_rgb.rotate(45,expand=True)
# Out:
# <PIL.Image.Image image mode=RGB size=99x99 at 0x7FB171749ED0>

# %%
from PIL import ImageDraw

# %%
draw = ImageDraw.Draw(im_rgb)

# %%
draw.text((10, 10)),"Hello Pillow",(0, 0, 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-452fe0d14670> in <module>()
# ----> 1 draw.text((10, 10)),"Hello Pillow",(0, 0, 0)
#
# TypeError: text() missing 1 required positional argument: 'text'

# %%
im_rgb
# Out:
# <PIL.Image.Image image mode=RGB size=85x53 at 0x7FB171743210>

# %%
from PIL import Image

# %%
im1 = Image.open("download-21.jpg")

# %%
im1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x7FB171719D90>

# %%
im1=im1.resize((85, 53))

# %%
im1
# Out:
# <PIL.Image.Image image mode=RGB size=85x53 at 0x7FB171749B10>

# %%
im_rgb.size
# Out:
# (85, 53)

# %%
im1.size
# Out:
# (85, 53)

# %%
print('im1 size: ', im1_size)
print('im size: ', im_size)
# Out:
# im1 size:  (85, 53)
# im size:  (85, 53)

# %%
new_im = Image.new('RGB', (2*im1_size[0],2*im1_size[1]), (150,150,150))

# %%
new_im.paste(im1, (0,0))

# %%
new_im.paste(im, (im1_size[0],0))

# %%
new_im.save("merged_images.png", "PNG")

# %%
new_im.show()

# %%
new_im
# Out:
# <PIL.Image.Image image mode=RGB size=170x106 at 0x7FB1686809D0>
